# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import balanced_accuracy_score,roc_auc_score,make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
df = pd.read_csv('ADNI_Training_Q3_APOE_CollectionADNI1Complete 1Yr 1.5T_July22.2014.csv',low_memory=False)

# %%
 df.head()
# Out:
#                      Measure:volume  Left-Lateral-Ventricle  \
# 0  031_S_4721-2018-12-14_14_45_04.0                 44037.0
# 1  002_S_4799-2018-06-14_07_58_09.0                 27207.0
# 2  053_S_5296-2018-11-28_11_40_58.0                 13347.0
# 3  002_S_1155-2018-05-08_13_06_40.0                 25798.0
# 4  052_S_1352-2018-09-13_10_10_00.0                 26632.0
#
#    Left-Inf-Lat-Vent  Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# 0             1996.0                       12397.0                 49202.0
# 1              829.0                       14113.0                 48615.0
# 2              502.0                       19866.0                 58068.0
# 3             1057.0                       14686.0                 50827.0
# 4             2138.0                       18645.0                 37461.0
#
#    Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# 0                6565.0        4085.0        4378.0         1567.0
# 1                6765.0        4122.0        5406.0         1931.0
# 2                8960.0        4011.0        6959.0         1740.0
# 3                6540.0        4386.0        5776.0         1640.0
# 4                6259.0        2810.0        4512.0         1455.0
#
#    3rd-Ventricle  ...  rh_superiorparietal_volume  rh_superiortemporal_volume  \
# 0         1966.0  ...                     11229.0                      9018.0
# 1         1681.0  ...                     15726.0                     11697.0
# 2         2407.0  ...                     13980.0                     14173.0
# 3         1711.0  ...                     14390.0                     12112.0
# 4         2798.0  ...                     14156.0                      8283.0
#
#    rh_supramarginal_volume  rh_frontalpole_volume  rh_temporalpole_volume  \
# 0                  10966.0                  992.0                  2659.0
# 1                  10839.0                 1031.0                  2959.0
# 2                  13154.0                  910.0                  2076.0
# 3                  11285.0                  932.0                  2098.0
# 4                  11410.0                 1470.0                  1922.0
#
#    rh_transversetemporal_volume  rh_insula_volume   RID  studyID    ScanDate
# 0                         838.0            6501.0  4721     4721  2018-12-14
# 1                        1296.0            7898.0  4799     4799  2018-06-14
# 2                        1148.0            9305.0  5296     5296  2018-11-28
# 3                         899.0            6577.0  1155     1155  2018-05-08
# 4                         574.0            6900.0  1352     1352  2018-09-13
#
# [5 rows x 129 columns]

# %%
df.drop(['RID','studyID','ScanDate'],
        axis=1,inplace=True)
df.head()
# Out:
#                      Measure:volume  Left-Lateral-Ventricle  \
# 0  031_S_4721-2018-12-14_14_45_04.0                 44037.0
# 1  002_S_4799-2018-06-14_07_58_09.0                 27207.0
# 2  053_S_5296-2018-11-28_11_40_58.0                 13347.0
# 3  002_S_1155-2018-05-08_13_06_40.0                 25798.0
# 4  052_S_1352-2018-09-13_10_10_00.0                 26632.0
#
#    Left-Inf-Lat-Vent  Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# 0             1996.0                       12397.0                 49202.0
# 1              829.0                       14113.0                 48615.0
# 2              502.0                       19866.0                 58068.0
# 3             1057.0                       14686.0                 50827.0
# 4             2138.0                       18645.0                 37461.0
#
#    Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# 0                6565.0        4085.0        4378.0         1567.0
# 1                6765.0        4122.0        5406.0         1931.0
# 2                8960.0        4011.0        6959.0         1740.0
# 3                6540.0        4386.0        5776.0         1640.0
# 4                6259.0        2810.0        4512.0         1455.0
#
#    3rd-Ventricle  ...  rh_rostralanteriorcingulate_volume  \
# 0         1966.0  ...                              1776.0
# 1         1681.0  ...                              2535.0
# 2         2407.0  ...                              3147.0
# 3         1711.0  ...                              2831.0
# 4         2798.0  ...                              1758.0
#
#    rh_rostralmiddlefrontal_volume  rh_superiorfrontal_volume  \
# 0                         13486.0                    18291.0
# 1                         17491.0                    21055.0
# 2                         15807.0                    26688.0
# 3                         15429.0                    22160.0
# 4                         16417.0                    21674.0
#
#    rh_superiorparietal_volume  rh_superiortemporal_volume  \
# 0                     11229.0                      9018.0
# 1                     15726.0                     11697.0
# 2                     13980.0                     14173.0
# 3                     14390.0                     12112.0
# 4                     14156.0                      8283.0
#
#    rh_supramarginal_volume  rh_frontalpole_volume  rh_temporalpole_volume  \
# 0                  10966.0                  992.0                  2659.0
# 1                  10839.0                 1031.0                  2959.0
# 2                  13154.0                  910.0                  2076.0
# 3                  11285.0                  932.0                  2098.0
# 4                  11410.0                 1470.0                  1922.0
#
#    rh_transversetemporal_volume  rh_insula_volume
# 0                         838.0            6501.0
# 1                        1296.0            7898.0
# 2                        1148.0            9305.0
# 3                         899.0            6577.0
# 4                         574.0            6900.0
#
# [5 rows x 126 columns]

# %%
df.drop(['Left-WM-hypointensities','Right-WM-hypointensities','Left-non-WM-hypointensities','Right-non-WM-hypointensities'],
        axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Measure:volume                   object
# Left-Lateral-Ventricle          float64
# Left-Inf-Lat-Vent               float64
# Left-Cerebellum-White-Matter    float64
# Left-Cerebellum-Cortex          float64
#                                  ...
# rh_supramarginal_volume         float64
# rh_frontalpole_volume           float64
# rh_temporalpole_volume          float64
# rh_transversetemporal_volume    float64
# rh_insula_volume                float64
# Length: 122, dtype: object

# %%
X = df.drop([Y,axis=]).copy(
y = df['y']).copy()

# %%
sum(y)/len(y)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_encoded,y,random_state=42,startify=y)
